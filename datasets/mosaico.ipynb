# %% [markdown]
# # Mosaico / Anatel
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/intrig-unicamp/hackathon5G/blob/main/datasets/mosaico.ipynb)
#
# Esse Notebook contém uma breve análise dos dados que o Mosaico dispõe. Os participantes são encorajados a experimentar com os dados para descobrir padrões, formas de resolver problemas no contexto da Hackathon.
#
# O Mosaico é um sistema da Agência Nacional de Telecomunicações (Anatel) que contém informações sobre todas as estações de telecomunicações registradas no Brasil. O sistema é utilizado para monitorar e controlar o espectro de frequências utilizado pelas operadoras de telecomunicações e outras empresas que possuem licenças para operar estações em território nacional. Entre os dados armazenados no Mosaico estão informações sobre os proprietários das estações, as tecnologias e equipamentos utilizados, as frequências de transmissão e recepção, a localização geográfica das estações e as datas de licenciamento e validade. O Mosaico é uma ferramenta importante para a ANATEL e outras autoridades regulatórias que precisam monitorar e controlar o uso do espectro de frequências de telecomunicações no Brasil, garantindo que as operadoras e outras empresas cumpram as regulamentações e leis aplicáveis.
#
# Os dados utilizados nesse Notebook foram extraídos [desse](https://sistemas.anatel.gov.br/se/public/view/b/licenciamento.php?view=licenciamento) endereço (Mosaico).

# %% [markdown]
# ## Instalação das dependências
#
# Instalar as dependências no ambiente adequado (pip ou Anaconda).

# %%
try:
    import google.colab as _
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    # !pip install pandas numpy seaborn scikit-learn plotly tqdm -q
else:
    # !conda install pandas numpy seaborn scikit-learn plotly tqdm -qy --freeze-installed
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /home/arthur/miniconda3
#
#   added / updated specs:
#     - numpy
#     - pandas
#     - plotly
#     - scikit-learn
#     - seaborn
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     plotly-5.14.1              |     pyhd8ed1ab_0         4.9 MB  conda-forge
#     scikit-learn-1.2.2         |   py39hd189fd4_1         7.3 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.1 MB
#
# The following packages will be UPDATED:
#
#   plotly                         plotly::plotly-5.10.0-py_0 --> conda-forge::plotly-5.14.1-pyhd8ed1ab_0
#   scikit-learn                         1.0.2-py39h4dfa638_0 --> 1.2.2-py39hd189fd4_1
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# ## Obtendo arquivos de dados
#
# Baixamos os arquivos caso o Notebook esteja sendo executado no ambiente do Google Colab. A variável de prefixo do caminho dos arquivos é definida de acordo.

# %%
if IN_COLAB:
    # !git clone --depth=1 https://github.com/intrig-unicamp/hackathon5G.git hackathon5G

DATA_PATH_PREFIX = './hackathon5G/datasets' if IN_COLAB else '.'

# %% [markdown]
# ## Importando dependências globais

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics.pairwise import haversine_distances

from math import radians
import requests
import json
import random

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Colunas
#
# Para facilitar a compreensão das colunas disponíveis, pode-se agrupá-las logicamente da seguinte forma:
#
# - **Identificação**: `NomeEntidade`, `NumEstacao`;
#
# - **Rádio**: `Tecnologia`, `tipoTecnologia`, `FreqTxMHz`, `FreqRxMHz`, `DesignacaoEmissao`, `meioAcesso`, `Polarizacao`, `GanhoAntena`, `PotenciaTransmissorWatts`, `AnguloMeiaPotenciaAntena`, `FrenteCostaAntena`;
#
# - **Posicionamento**: `Azimute`, `AlturaAntena`, `AnguloElevacao`;
#
# - **Localização**: `Latitude`, `Longitude`, `EnderecoEstacao`, `EndComplemento`, `SiglaUf`, `CodMunicipio`;
#
# - **Regulamentação e Licenciamento**: `NumFistel`, `NumFistelAssociado`, `NumAto`, `DataLicenciamento`, `DataPrimeiroLicenciamento`, `DataValidade`, `CodDebitoTFI`;
#
# - _Outros_: `CodTipoClasseEstacao`, `ClassInfraFisica`, `CompartilhamentoInfraFisica`, `CodTipoAntena`, `CodEquipamentoAntena`, `CodEquipamentoTransmissor`, `NumRede`, `NumServico`, `NomeEntidadeAssociado`, `Status.state`, `_id`.

# %% [markdown]
# ## Carregando os dados

# %%
MOSAICO_PATH = f'{DATA_PATH_PREFIX}/mosaico'

regions = [
    'são-paulo',
    'campinas',
    'rio-de-janeiro',
    'brasília',
]

ERBs = pd.concat([ pd.read_csv(f'{MOSAICO_PATH}/mosaico-erbs-{region}.zip', encoding='iso-8859-1', low_memory=False) for region in regions ], ignore_index=True, copy=True)
ERBs
# Out:
#         Status.state            NomeEntidade    NumFistel  NumServico
# 0         LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10  \
# 1         LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 2         LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 3         LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 4         LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# ...              ...                     ...          ...         ...
# 1218865   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146366          10
# 1218866   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146366          10
# 1218867   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146366          10
# 1218868   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146366          10
# 1218869   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146366          10
#
#              NumAto  NumEstacao               EnderecoEstacao EndComplemento
# 0        17012008.0      122700  Rua Manoel Duque de Carvalho            NaN  \
# 1        35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# 2        35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# 3        35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# 4        35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# ...             ...         ...                           ...            ...
# 1218865  35312011.0  1014783507      SHIS QI. 12 CONJUNTO 8/9            NaN
# 1218866  17012008.0  1014783507      SHIS QI. 12 CONJUNTO 8/9            NaN
# 1218867  17012008.0  1014783507      SHIS QI. 12 CONJUNTO 8/9            NaN
# 1218868  50852013.0  1014783507      SHIS QI. 12 CONJUNTO 8/9            NaN
# 1218869  50852013.0  1014783507      SHIS QI. 12 CONJUNTO 8/9            NaN
#
#         SiglaUf  CodMunicipio DesignacaoEmissao Tecnologia tipoTecnologia
# 0            SP       3550308           5M00G9W      WCDMA            NaN  \
# 1            SP       3550308           200KG7W        GSM            NaN
# 2            SP       3550308           200KG7W        GSM            NaN
# 3            SP       3550308           200KG7W        GSM            NaN
# 4            SP       3550308           200KG7W        GSM            NaN
# ...         ...           ...               ...        ...            ...
# 1218865      DF       5300108           10M0G7W        LTE            NaN
# 1218866      DF       5300108           10M0G7W        LTE            NaN
# 1218867      DF       5300108           10M0G7W        LTE            NaN
# 1218868      DF       5300108           5M00G7W        LTE            NaN
# 1218869      DF       5300108           5M00G7W        LTE            NaN
#
#          meioAcesso  FreqTxMHz  FreqRxMHz Azimute CodTipoClasseEstacao
# 0               NaN     2160.0     1970.0     230                   FB  \
# 1               NaN     1862.5     1767.5     360                   FB
# 2               NaN     1862.5     1767.5     130                   FB
# 3               NaN     1867.5     1772.5     130                   FB
# 4               NaN     1867.5     1772.5     240                   FB
# ...             ...        ...        ...     ...                  ...
# 1218865         NaN     1855.0     1760.0    65.0                   FB
# 1218866         NaN     2160.0     1970.0   335.0                   FB
# 1218867         NaN     2160.0     1970.0    65.0                   FB
# 1218868         NaN     2167.5     1977.5   335.0                   FB
# 1218869         NaN     2167.5     1977.5    65.0                   FB
#
#         ClassInfraFisica CompartilhamentoInfraFisica CodTipoAntena
# 0                    NaN                         NaN           760  \
# 1                    NaN                         NaN           760
# 2                    NaN                         NaN           760
# 3                    NaN                         NaN           760
# 4                    NaN                         NaN           760
# ...                  ...                         ...           ...
# 1218865              NaN                         NaN           760
# 1218866              NaN                         NaN           760
# 1218867              NaN                         NaN           760
# 1218868              NaN                         NaN           760
# 1218869              NaN                         NaN           760
#
#         CodEquipamentoAntena GanhoAntena FrenteCostaAntena
# 0               002000703518        14.9                25  \
# 1               038801200762        17.8                25
# 2               038801200762        17.8                25
# 3               038801200762        17.8                25
# 4               038801200762        17.8                25
# ...                      ...         ...               ...
# 1218865                  NaN          13              20.0
# 1218866                  NaN        13.3              20.0
# 1218867                  NaN        13.3              20.0
# 1218868                  NaN        13.3              20.0
# 1218869                  NaN        13.3              20.0
#
#         AnguloMeiaPotenciaAntena AnguloElevacao Polarizacao AlturaAntena
# 0                             70              6           X           41  \
# 1                             65              5           X           39
# 2                             65              5           X           39
# 3                             65              5           X           39
# 4                             65              5           X           39
# ...                          ...            ...         ...          ...
# 1218865                       63            0.0           X          4.0
# 1218866                       62            0.0           X          4.0
# 1218867                       62            0.0           X          4.0
# 1218868                       62            0.0           X          4.0
# 1218869                       62            0.0           X          4.0
#
#         CodEquipamentoTransmissor PotenciaTransmissorWatts  Latitude
# 0                    018930701882                     39.4 -23.71889  \
# 1                    006030301882                     15.8 -23.71889
# 2                    006030301882                     15.8 -23.71889
# 3                    006030301882                     15.8 -23.71889
# 4                    006030301882                     15.8 -23.71889
# ...                           ...                      ...       ...
# 1218865              083071803257                       40 -15.83168
# 1218866              083071803257                       40 -15.83168
# 1218867              083071803257                       40 -15.83168
# 1218868              083071803257                       40 -15.83168
# 1218869              083071803257                       40 -15.83168
#
#          Longitude CodDebitoTFI DataLicenciamento DataPrimeiroLicenciamento
# 0        -46.68889            G        2021-12-24                1999-12-10  \
# 1        -46.68889            G        2021-12-24                1999-12-10
# 2        -46.68889            G        2021-12-24                1999-12-10
# 3        -46.68889            G        2021-12-24                1999-12-10
# 4        -46.68889            G        2021-12-24                1999-12-10
# ...            ...          ...               ...                       ...
# 1218865  -47.86179            G        2023-03-21                2023-03-21
# 1218866  -47.86179            G        2023-03-21                2023-03-21
# 1218867  -47.86179            G        2023-03-21                2023-03-21
# 1218868  -47.86179            G        2023-03-21                2023-03-21
# 1218869  -47.86179            G        2023-03-21                2023-03-21
#
#         NumRede               _id DataValidade  NumFistelAssociado
# 0           NaN     4d5c019f58e6a   2023-04-30                 NaN  \
# 1           NaN     4d5c019f58e6b   2023-04-30                 NaN
# 2           NaN     4d5c019f58e6c   2023-04-30                 NaN
# 3           NaN     4d5c019f58e6d   2023-04-30                 NaN
# 4           NaN     4d5c019f58e6e   2023-04-30                 NaN
# ...         ...               ...          ...                 ...
# 1218865     NaN  5ae855f89dc02039   2023-04-30                 NaN
# 1218866     NaN  5ae855f89dc0203a   2023-04-30                 NaN
# 1218867     NaN  5ae855f89dc0203b   2023-04-30                 NaN
# 1218868     NaN  5ae855f89dc0203c   2023-04-30                 NaN
# 1218869     NaN  5ae855f89dc0203d   2023-04-30                 NaN
#
#         NomeEntidadeAssociado
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 1218865                   NaN
# 1218866                   NaN
# 1218867                   NaN
# 1218868                   NaN
# 1218869                   NaN
#
# [1218870 rows x 40 columns]

# %% [markdown]
# ## Normalização dos valores

# %% [markdown]
# Na célula abaixo, identificamos os possíveis valores da coluna `Tecnologia`, em seguida, os normalizamos e criamos outro campo com o mapeamento para a geração da tecnologia (_e.g._ `LTE` → `4G`, `NR` → `5G`)

# %%
ERBs.Tecnologia.unique()
# Out:
# array(['WCDMA', 'GSM', 'LTE', 'NR', 'CDMA', nan, 'DMR', 'VHF', 'UHF',
#        '0.0', 'TETRA', 'DMR - Tyer 2', 'WDCMA', 'NR ', 'LTE ', 'EDGE',
#        'UMTS', 'Tetra'], dtype=object)

# %%
ERBs.replace({ 'Tecnologia': { 'NR ': 'NR', 'WDCMA': 'WCDMA' } }, inplace=True)

# %%
ERBs['Tecnologia_gen'] = ERBs.Tecnologia.map({ 'GSM': '2G', 'WCDMA': '3G', 'LTE': '4G', 'NR': '5G' })

# %% [markdown]
# A seguir, normalizamos os valores do azimute

# %%
ERBs.Azimute = ERBs.Azimute.str.replace(',', '.').replace('V', np.nan).astype(np.float64)

# %% [markdown]
# # Exploração

# %%
ERBs.NomeEntidade[(ERBs.NomeEntidade.str.contains('claro', case=False))].unique()
# Out:
# array(['CLARO S.A.'], dtype=object)

# %%
ERBs_SP_CLARO = ERBs[(ERBs.SiglaUf == 'SP') & (ERBs.NomeEntidade == 'CLARO S.A.')].copy()
ERBs_SP_CLARO
# Out:
#        Status.state NomeEntidade    NumFistel  NumServico       NumAto  \
# 200      LIC-LIC-01   CLARO S.A.  50409105090          10   46662011.0
# 201      LIC-LIC-01   CLARO S.A.  50409105090          10   46662011.0
# 202      LIC-LIC-01   CLARO S.A.  50409105090          10   46662011.0
# 203      LIC-LIC-01   CLARO S.A.  50409105090          10   46662011.0
# 204      LIC-LIC-01   CLARO S.A.  50409105090          10   46662011.0
# ...             ...          ...          ...         ...          ...
# 861976   LIC-LIC-01   CLARO S.A.  50409105090          10  105752021.0
# 861977   LIC-LIC-01   CLARO S.A.  50409105090          10  105752021.0
# 861978   LIC-LIC-01   CLARO S.A.  50409105090          10  105752021.0
# 861979   LIC-LIC-01   CLARO S.A.  50409105090          10  105752021.0
# 861980   LIC-LIC-01   CLARO S.A.  50409105090          10  105752021.0
#
#         NumEstacao             EnderecoEstacao          EndComplemento  \
# 200        1246232  R GASPAR GONÇALVES RIBEIRO                       0
# 201        1246232  R GASPAR GONÇALVES RIBEIRO                       0
# 202        1246232  R GASPAR GONÇALVES RIBEIRO                       0
# 203        1246232  R GASPAR GONÇALVES RIBEIRO                       0
# 204        1246232  R GASPAR GONÇALVES RIBEIRO                       0
# ...            ...                         ...                     ...
# 861976  1004778756          RUA MARIA MONTEIRO  ED PERO VAZ DE CAMINHA
# 861977  1004778756          RUA MARIA MONTEIRO  ED PERO VAZ DE CAMINHA
# 861978  1007421077           RUA LUIZ DE PAULA                     NaN
# 861979  1007421077           RUA LUIZ DE PAULA                     NaN
# 861980  1007421077           RUA LUIZ DE PAULA                     NaN
#
#        SiglaUf  CodMunicipio DesignacaoEmissao Tecnologia tipoTecnologia  \
# 200         SP       3550308           5M00G7W      WCDMA            NaN
# 201         SP       3550308           5M00G7W      WCDMA            NaN
# 202         SP       3550308           5M00G7W      WCDMA            NaN
# 203         SP       3550308           5M00G7W      WCDMA            NaN
# 204         SP       3550308           200KG7W        GSM            NaN
# ...        ...           ...               ...        ...            ...
# 861976      SP       3509502           100MG7W         NR         SA-NSA
# 861977      SP       3509502           100MG7W         NR         SA-NSA
# 861978      SP       3509502           100MG7W         NR         SA-NSA
# 861979      SP       3509502           100MG7W         NR         SA-NSA
# 861980      SP       3509502           100MG7W         NR         SA-NSA
#
#         meioAcesso  FreqTxMHz  FreqRxMHz  Azimute CodTipoClasseEstacao  \
# 200            NaN      885.0      840.0     20.0                   FB
# 201            NaN      885.0      840.0    120.0                   FB
# 202            NaN      885.0      840.0    260.0                   FB
# 203            NaN      885.0      840.0     20.0                   FB
# 204            NaN     1825.0     1730.0     20.0                   FB
# ...            ...        ...        ...      ...                  ...
# 861976         NaN     3350.0     3350.0      NaN                   FB
# 861977         NaN     3350.0     3350.0      NaN                   FB
# 861978         NaN     3350.0     3350.0      NaN                   FB
# 861979         NaN     3350.0     3350.0      NaN                   FB
# 861980         NaN     3350.0     3350.0      NaN                   FB
#
#        ClassInfraFisica CompartilhamentoInfraFisica CodTipoAntena  \
# 200          Greenfield                         não           760
# 201          Greenfield                         não           760
# 202          Greenfield                         não           760
# 203          Greenfield                         não           760
# 204          Greenfield                         não           760
# ...                 ...                         ...           ...
# 861976              NaN                         NaN           760
# 861977              NaN                         NaN           760
# 861978              NaN                         NaN           760
# 861979              NaN                         NaN           760
# 861980              NaN                         NaN           760
#
#        CodEquipamentoAntena GanhoAntena FrenteCostaAntena  \
# 200            009371303519       14.89                30
# 201            009371303519       14.89                30
# 202            009371303519       14.89                30
# 203            009371303519       14.89                30
# 204            027331703519       16.16                27
# ...                     ...         ...               ...
# 861976                  NaN          23              25.0
# 861977                  NaN        24.9              25.0
# 861978                  NaN          23              25.0
# 861979                  NaN          23              25.0
# 861980                  NaN          23              25.0
#
#        AnguloMeiaPotenciaAntena AnguloElevacao Polarizacao AlturaAntena  \
# 200                       65.28              6           X           35
# 201                       65.28              7           X           35
# 202                       65.28              9           X           35
# 203                       65.28              6           X           35
# 204                       66.76              2           X           35
# ...                         ...            ...         ...          ...
# 861976                     13.5           -1.0           X         40.0
# 861977                     13.5           -2.0           X         40.0
# 861978                     13.5            0.0           X         50.0
# 861979                     13.5            0.0           X         50.0
# 861980                     13.5            0.0           X         50.0
#
#        CodEquipamentoTransmissor PotenciaTransmissorWatts  Latitude  \
# 200                 039721705894                       80 -23.72650
# 201                 039721705894                       80 -23.72650
# 202                 039721705894                       80 -23.72650
# 203                 039721705894                       80 -23.72650
# 204                 006091702519                    79.43 -23.72650
# ...                          ...                      ...       ...
# 861976              072212102519                      200 -22.89167
# 861977              102792102519                      200 -22.89167
# 861978              072212102519                      200 -22.86949
# 861979              072212102519                      200 -22.86949
# 861980              072212102519                      200 -22.86949
#
#         Longitude CodDebitoTFI DataLicenciamento DataPrimeiroLicenciamento  \
# 200     -46.70350            G        2021-07-14                2002-10-16
# 201     -46.70350            G        2021-07-14                2002-10-16
# 202     -46.70350            G        2021-07-14                2002-10-16
# 203     -46.70350            G        2021-07-14                2002-10-16
# 204     -46.70350            G        2021-07-14                2002-10-16
# ...           ...          ...               ...                       ...
# 861976  -47.05333            G        2023-01-31                2017-07-25
# 861977  -47.05333            G        2023-01-31                2017-07-25
# 861978  -46.96741            G        2023-01-31                2018-10-26
# 861979  -46.96741            G        2023-01-31                2018-10-26
# 861980  -46.96741            G        2023-01-31                2018-10-26
#
#        NumRede               _id DataValidade  NumFistelAssociado  \
# 200        NaN     4d5c019f5b36e   2027-08-06                 NaN
# 201        NaN     4d5c019f5b36f   2027-08-06                 NaN
# 202        NaN     4d5c019f5b370   2027-08-06                 NaN
# 203        NaN     4d5c019f5b371   2027-08-06                 NaN
# 204        NaN     4d5c019f5b372   2027-08-06                 NaN
# ...        ...               ...          ...                 ...
# 861976     NaN  6ae915f872a88a9b   2028-03-31                 NaN
# 861977     NaN  6ae915f872a88a9c   2028-03-31                 NaN
# 861978     NaN  6ae915f872a88aca   2028-03-31                 NaN
# 861979     NaN  6ae915f872a88acb   2028-03-31                 NaN
# 861980     NaN  6ae915f872a88acc   2028-03-31                 NaN
#
#        NomeEntidadeAssociado Tecnologia_gen
# 200                      NaN             3G
# 201                      NaN             3G
# 202                      NaN             3G
# 203                      NaN             3G
# 204                      NaN             2G
# ...                      ...            ...
# 861976                   NaN             5G
# 861977                   NaN             5G
# 861978                   NaN             5G
# 861979                   NaN             5G
# 861980                   NaN             5G
#
# [86722 rows x 41 columns]

# %%
ERBs_SP_CLARO[ERBs_SP_CLARO.NumEstacao  == 1247468][['Tecnologia', 'tipoTecnologia']]
# Out:
#        Tecnologia tipoTecnologia
# 217         WCDMA            NaN
# 218           GSM            NaN
# 219           GSM            NaN
# 220           GSM            NaN
# 221           LTE            NaN
# 222           LTE            NaN
# 223           LTE            NaN
# 224         WCDMA            NaN
# 225         WCDMA            NaN
# 226         WCDMA            NaN
# 227         WCDMA            NaN
# 228         WCDMA            NaN
# 52092         LTE            NaN
# 52093         LTE            NaN
# 52094         LTE            NaN
# 84362         GSM            NaN
# 84363         GSM            NaN
# 84364         GSM            NaN
# 101737        LTE            NaN
# 101738        LTE            NaN
# 101739        LTE            NaN
# 370025        LTE            NaN
# 370026        LTE            NaN
# 370027        LTE            NaN
# 370028        LTE            NaN
# 370029        LTE            NaN
# 370030        LTE            NaN
# 370031        LTE            NaN
# 370032        LTE            NaN
# 370033        LTE            NaN
# 370034        LTE            NaN
# 370035        LTE            NaN
# 370036        LTE            NaN
# 370037        GSM            NaN
# 370038        GSM            NaN
# 370039        GSM            NaN
# 406744         NR         SA-NSA
# 406745         NR         SA-NSA
# 406746         NR         SA-NSA

# %%
# The Haversine (or great circle) distance is the angular distance
# between two points on the surface of a sphere. The first coordinate
# of each point is assumed to be the latitude, the second is the longitude,
# given in radians. The dimension of the data must be 2.

target = pd.DataFrame([[-23.555683, -46.662222]]).applymap(radians)
#target = pd.DataFrame([[-23.571094, -46.644239]]).applymap(radians)
distance = haversine_distances(ERBs_SP_CLARO[['Latitude', 'Longitude']].applymap(radians), target)
ERBs_SP_CLARO['distance'] = (distance * 6371000).round(3)  # multiply by Earth radius in meters
ERBs_SP_CLARO[(ERBs_SP_CLARO.distance < 2000)].groupby(['NumEstacao']).first().reset_index().sort_values('distance')
# Out:
#      NumEstacao Status.state NomeEntidade    NumFistel  NumServico  \
# 58    683887904   LIC-LIC-01   CLARO S.A.  50409105090          10
# 122  1000752124   LIC-LIC-01   CLARO S.A.  11021017965         175
# 204  1001532705   LIC-LIC-01   CLARO S.A.  50403922577          45
# 253  1014365217   LIC-LIC-01   CLARO S.A.  11021017965         175
# 244  1011649664   LIC-LIC-01   CLARO S.A.  50409105090          10
# ..          ...          ...          ...          ...         ...
# 70    683895150   LIC-LIC-01   CLARO S.A.  50409105090          10
# 247  1014365152   LIC-LIC-01   CLARO S.A.  11021017965         175
# 136  1000752663   LIC-LIC-01   CLARO S.A.  11021017965         175
# 172  1001314198   LIC-LIC-01   CLARO S.A.  50403922577          45
# 182  1001508642   LIC-LIC-01   CLARO S.A.  50403922577          45
#
#           NumAto                           EnderecoEstacao  \
# 58    46662011.0                             R BELA CINTRA
# 122  280462002.0            Rua Bela Cintra 968 Consolação
# 204  626492006.0            Rua Bela Cintra 968 Consolação
# 253   93272014.0                               AV PAULISTA
# 244   34672011.0                               AV PAULISTA
# ..           ...                                       ...
# 70    46662011.0           R SÃO DOMINGOS, 148, BELA VISTA
# 247   54202016.0                                 R CACONDE
# 136  280462002.0           Rua Caconde 317 Jardim Paulista
# 172  626492006.0           Rua Caconde 317 Jardim Paulista
# 182  626492006.0  Rua Frederico Abranches 168 Vila Buarque
#
#                             EndComplemento SiglaUf  CodMunicipio  \
# 58   COND. EDIFÍCIO QUARTIER OFFICE CENTER      SP       3550308
# 122                                   None      SP       3550308
# 204                                   None      SP       3550308
# 253              EDIFICIO SAO LUIZ GONZAGA      SP       3550308
# 244                                   None      SP       3550308
# ..                                     ...     ...           ...
# 70                                    None      SP       3550308
# 247                                      0      SP       3550308
# 136                                   None      SP       3550308
# 172                                   None      SP       3550308
# 182                                   None      SP       3550308
#
#                                      DesignacaoEmissao Tecnologia  \
# 58                                             5M00G7W      WCDMA
# 122                                            5M00G7W       None
# 204                                            5M00G7W       None
# 253                                            5M00G7W      WCDMA
# 244                                            5M00G7W      WCDMA
# ..                                                 ...        ...
# 70                                             200KG7W        GSM
# 247  200KG7W / 5M00G7W / 10M0G7W / 5M00D7W / 10M0D7...        GSM
# 136                                            5M00D9W       None
# 172                                            5M00D9W       None
# 182                                            5M00G7W       None
#
#     tipoTecnologia  meioAcesso  FreqTxMHz  FreqRxMHz  Azimute  \
# 58             NSA         NaN      885.0      840.0      5.0
# 122           None         NaN      882.8      837.8    350.0
# 204           None         NaN      885.0      840.0     90.0
# 253           None         NaN     2130.0     1940.0      0.0
# 244           None         NaN     2140.0     1950.0      0.0
# ..             ...         ...        ...        ...      ...
# 70            None         NaN     1830.0     1820.0    350.0
# 247           None         NaN     1825.0     1730.0    170.0
# 136           None         NaN      882.8      837.8    180.0
# 172           None         NaN      885.0      840.0    180.0
# 182           None         NaN      885.0      840.0     50.0
#
#     CodTipoClasseEstacao ClassInfraFisica CompartilhamentoInfraFisica  \
# 58                    FB          Rooftop                        None
# 122                   FX             None                        None
# 204                   FX             None                        None
# 253                   FB             None                        None
# 244                   FB      Ran Sharing                         não
# ..                   ...              ...                         ...
# 70                    FB          Rooftop                         sim
# 247                   FB             None                        None
# 136                   FX             None                        None
# 172                   FX             None                        None
# 182                   FX             None                        None
#
#      CodTipoAntena CodEquipamentoAntena  GanhoAntena FrenteCostaAntena  \
# 58             760         056001603518        14.00                23
# 122            817          37751200762        14.00                35
# 204            760         026591200762        14.40              33.0
# 253            168         012110501403         4.70                 0
# 244            168         000000INDOOR         4.70                 0
# ..             ...                  ...          ...               ...
# 70             760         027331703519        16.16              27.0
# 247            760         056001603518        14.89                30
# 136            817          28661005344        13.50                28
# 172            760         004620601705        13.50              28.0
# 182            760         026591200762        14.40              33.0
#
#     AnguloMeiaPotenciaAntena AnguloElevacao Polarizacao AlturaAntena  \
# 58                        62              0           X           50
# 122                     70.6              2           X           51
# 204                    66.37           2.00           X         51.0
# 253                      360              0           V            2
# 244                      360              0           V            3
# ..                       ...            ...         ...          ...
# 70                     66.76            2.0           X         32.4
# 247                    65.28              3           X         42.9
# 136                     58.9             16           X           44
# 172                    58.90          16.00           X         44.0
# 182                    66.40           4.00           X         44.0
#
#     CodEquipamentoTransmissor PotenciaTransmissorWatts   Latitude  Longitude  \
# 58               039721705894                       80 -23.555430 -46.661160
# 122              010641001882                     63.5 -23.555486 -46.661058
# 204              010641001882                   63.500 -23.555486 -46.661056
# 253              006801103257                    36.98 -23.556717 -46.661307
# 244              006801103257                    36.98 -23.556720 -46.661310
# ..                        ...                      ...        ...        ...
# 70               006091702519                     79.4 -23.551940 -46.643330
# 247              040952002519                       60 -23.573400 -46.659700
# 136              008940701882                    48.87 -23.573400 -46.659700
# 172              008940701882                   48.900 -23.573400 -46.659697
# 182              010641001882                   63.500 -23.542578 -46.648800
#
#     CodDebitoTFI DataLicenciamento DataPrimeiroLicenciamento  NumRede  \
# 58             G        2022-08-03                2003-12-15      NaN
# 122            C        2020-03-28                2015-06-03   9334.0
# 204            A        2015-05-28                2015-05-28      NaN
# 253            C        2022-10-20                2022-10-20      NaN
# 244            G        2022-06-23                2021-01-07      NaN
# ..           ...               ...                       ...      ...
# 70             G        2020-07-27                2003-12-15      NaN
# 247            C        2022-10-20                2022-10-20      NaN
# 136            C        2020-03-28                2015-06-03   9352.0
# 172            A        2015-05-26                2015-05-26      NaN
# 182            A        2015-05-28                2015-05-28      NaN
#
#                   _id DataValidade  NumFistelAssociado NomeEntidadeAssociado  \
# 58      4d5c01a01349f   2027-08-06                 NaN                  None
# 122  265b3f0811f76659   2024-02-08                 NaN                  None
# 204  265b3f0811f45251   2028-11-29                 NaN                  None
# 253  af8bc5f861901149   2027-07-02                 NaN                  None
# 244     600599300b79d   2026-06-01                 NaN                  None
# ..                ...          ...                 ...                   ...
# 70      4d5c01a01426b   2027-08-06                 NaN                  None
# 247  af8bc5f86190112b   2027-07-02                 NaN                  None
# 136  265b3f0811f70b9b   2024-02-08                 NaN                  None
# 172  265b3f0811f407b5   2028-11-29                 NaN                  None
# 182  265b3f0811f447a2   2028-11-29                 NaN                  None
#
#     Tecnologia_gen  distance
# 58              3G   111.845
# 122           None   120.651
# 204           None   120.894
# 253             3G   148.046
# 244             3G   148.113
# ..             ...       ...
# 70              2G  1970.140
# 247             2G  1986.739
# 136           None  1986.739
# 172           None  1986.776
# 182           None  1998.850
#
# [256 rows x 42 columns]

# %%
df = ERBs_SP_CLARO[(ERBs_SP_CLARO.distance < 8000) & (ERBs_SP_CLARO.Tecnologia == 'NR')].sort_values('distance')
df.Latitude = df.Latitude.apply(lambda val: val + random.random() / 10**4)

# %%
df.Longitude = df.Longitude.apply(lambda val: val + random.random() / 10**4)

# %%
ERBs_SP_CLARO['Azimute_rad'] = ERBs_SP_CLARO.Azimute.apply(lambda val: val * np.pi/180)

# %%
ERBs_SP_CLARO[['Azimute', 'Azimute_rad']]
# Out:
#         Azimute  Azimute_rad
# 200        20.0     0.349066
# 201       120.0     2.094395
# 202       260.0     4.537856
# 203        20.0     0.349066
# 204        20.0     0.349066
# ...         ...          ...
# 861976      NaN          NaN
# 861977      NaN          NaN
# 861978      NaN          NaN
# 861979      NaN          NaN
# 861980      NaN          NaN
#
# [86722 rows x 2 columns]

# %%
import plotly.express as px

fig = px.scatter_mapbox(df, lat="Latitude", lon="Longitude", hover_name="NumEstacao", color="FreqTxMHz", #size="car_hours",
                  color_continuous_scale=px.colors.qualitative.Alphabet, size_max=20, zoom=13,  width=1000, height=1000)
fig.update_layout(
                        mapbox={
        #'style': "carto-darkmatter",
        #'style': "carto-positron",
        #'style': "open-street-map",
        'style': "stamen-toner",
        #'style': "stamen-watercolor",
        #'style': "white-bg",
                        },
                       )
#fig
#fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0f407978-950a-466f-82ae-fdb76d8967cc" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f407978-950a-466f-82ae-fdb76d8967cc")) {                    Plotly.newPlot(                        "0f407978-950a-466f-82ae-fdb76d8967cc",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Latitude=%{lat}<br>Longitude=%{lon}<br>FreqTxMHz=%{marker.color}<extra></extra>","hovertext":[683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,442158556.0,442158556.0,442158556.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,690901321.0,690901321.0,690901321.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,688033202. ...

# %%
import plotly.express as px

df = ERBs_SP_CLARO[(ERBs_SP_CLARO.distance < 50000) & (ERBs_SP_CLARO.Tecnologia == 'NR')].sort_values('distance')
df.Latitude = df.Latitude.apply(lambda val: val + random.random() / 10**4)
df.Longitude = df.Longitude.apply(lambda val: val + random.random() / 10**4)

fig = px.scatter_mapbox(df, lat="Latitude", lon="Longitude", hover_name="NumEstacao", color="FreqTxMHz", #size="car_hours",
                  color_continuous_scale=px.colors.qualitative.Alphabet, size_max=20, zoom=13,  width=1000, height=1000)
fig.update_layout(
                        mapbox={
        #'style': "carto-darkmatter",
        #'style': "carto-positron",
        #'style': "open-street-map",
        'style': "stamen-toner",
        #'style': "stamen-watercolor",
        #'style': "white-bg",
                        },
                       )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c566de6a-893c-4f6f-a7e2-2b15c75e47a5" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c566de6a-893c-4f6f-a7e2-2b15c75e47a5")) {                    Plotly.newPlot(                        "c566de6a-893c-4f6f-a7e2-2b15c75e47a5",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Latitude=%{lat}<br>Longitude=%{lon}<br>FreqTxMHz=%{marker.color}<extra></extra>","hovertext":[683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,683887904.0,442158556.0,442158556.0,442158556.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,684147530.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,3428370.0,690901321.0,690901321.0,690901321.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,684147360.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,405602804.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1005933011.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,1349821.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,683887840.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,682813052.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,683893645.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,431368082.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,683889133.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1009256448.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,1008537770.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,683893700.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,684595028.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683893629.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,683843540.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,684259192.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,2164060.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,684338033.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683032020.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,683935518.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,431055688.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,684147432.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,683887807.0,688033202. ...

# %%
ERBs[(ERBs.NumEstacao  == 683887904) & (ERBs.Tecnologia == 'LTE')][['Tecnologia', 'tipoTecnologia', 'DesignacaoEmissao', 'FreqTxMHz', 'FreqRxMHz']]
#9610
# Out:
#        Tecnologia tipoTecnologia DesignacaoEmissao  FreqTxMHz  FreqRxMHz
# 18214         LTE            NaN           20M0G7W     2640.0     2520.0
# 18215         LTE            NaN           20M0G7W     2640.0     2520.0
# 18216         LTE            NaN           20M0G7W     2640.0     2520.0
# 53925         LTE            NaN           5M00G7W     1825.0     1730.0
# 53926         LTE            NaN           5M00G7W     1825.0     1730.0
# 53927         LTE            NaN           5M00G7W     1825.0     1730.0
# 58251         LTE            NaN           10M0G7W      798.0      743.0
# 58252         LTE            NaN           10M0G7W      798.0      743.0
# 58253         LTE            NaN           10M0G7W      798.0      743.0
# 86658         LTE            NaN           5M00G7W     1825.0     1730.0
# 86659         LTE            NaN           5M00G7W     1825.0     1730.0
# 86660         LTE            NaN           5M00G7W     1825.0     1730.0
# 86661         LTE            NaN           10M0G7W     2130.0     1940.0
# 86662         LTE            NaN           10M0G7W     2130.0     1940.0
# 86663         LTE            NaN           10M0G7W     2130.0     1940.0
# 95079         LTE            NaN           15M0G7W     1842.5     1747.5
# 95080         LTE            NaN           15M0G7W     1842.5     1747.5
# 95081         LTE            NaN           15M0G7W     1842.5     1747.5
# 95082         LTE            NaN           15M0G7W     1842.5     1747.5
# 95083         LTE            NaN           15M0G7W     1842.5     1747.5
# 95084         LTE            NaN           15M0G7W     1842.5     1747.5
# 371762        LTE            NaN           10M0G7W     2140.0     1950.0
# 371763        LTE            NaN           10M0G7W     2140.0     1950.0
# 371764        LTE            NaN           10M0G7W     2140.0     1950.0

# %%
ERBs_SP_CLARO.groupby(['Tecnologia', 'tipoTecnologia'], dropna=False).first()[[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [(GSM, nan), (LTE, nan), (NR, NSA), (NR, SA), (NR, SA-NSA), (NR, nan), (WCDMA, nan), (nan, nan)]

# %%
ERBs.groupby(['Tecnologia_gen', 'tipoTecnologia', 'SiglaUf'], dropna=False).count()[['Status.state']]
# Out:
#                                        Status.state
# Tecnologia_gen tipoTecnologia SiglaUf
# 2G             NaN            DF               7681
#                               RJ              21799
#                               SP              24627
# 3G             NaN            DF              18362
#                               RJ              37605
#                               SP              51062
# 4G             NaN            DF              26180
#                               RJ              57513
#                               SP              87937
# 5G             NSA            DF                924
#                               RJ                  9
#                               SP                591
#                SA             DF                273
#                               SP                 33
#                SA-NSA         DF               3091
#                               RJ               6661
#                               SP              12851
#                NaN            DF                 81
#                               RJ                564
#                               SP                598
# NaN            0.0            SP                 12
#                DMR Tyer 2     RJ                  7
#                               SP                  2
#                NaN            DF              48373
#                               RJ             127766
#                               SP             684268

# %%
ERBs[ERBs.CodMunicipio == 3550308]
# Out:
#        Status.state            NomeEntidade    NumFistel  NumServico  \
# 0        LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 1        LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 2        LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 3        LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 4        LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# ...             ...                     ...          ...         ...
# 726315   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 726316   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 726317   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 726318   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
# 726319   LIC-LIC-01  TELEFONICA BRASIL S.A.  50409146447          10
#
#             NumAto  NumEstacao               EnderecoEstacao EndComplemento  \
# 0       17012008.0      122700  Rua Manoel Duque de Carvalho            NaN
# 1       35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# 2       35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# 3       35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# 4       35312011.0      122700  Rua Manoel Duque de Carvalho            NaN
# ...            ...         ...                           ...            ...
# 726315  35312011.0  1000598664       RUA JOSUÉ CARMINO BRUNO            NaN
# 726316  35312011.0  1000598664       RUA JOSUÉ CARMINO BRUNO            NaN
# 726317  41662008.0  1000598664       RUA JOSUÉ CARMINO BRUNO            NaN
# 726318  41662008.0  1000598664       RUA JOSUÉ CARMINO BRUNO            NaN
# 726319  41662008.0  1000598664       RUA JOSUÉ CARMINO BRUNO            NaN
#
#        SiglaUf  CodMunicipio DesignacaoEmissao Tecnologia tipoTecnologia  \
# 0           SP       3550308           5M00G9W      WCDMA            NaN
# 1           SP       3550308           200KG7W        GSM            NaN
# 2           SP       3550308           200KG7W        GSM            NaN
# 3           SP       3550308           200KG7W        GSM            NaN
# 4           SP       3550308           200KG7W        GSM            NaN
# ...        ...           ...               ...        ...            ...
# 726315      SP       3550308           5M00G7W        LTE            NaN
# 726316      SP       3550308           5M00G7W        LTE            NaN
# 726317      SP       3550308           5M00G7W      WCDMA            NaN
# 726318      SP       3550308           5M00G7W      WCDMA            NaN
# 726319      SP       3550308           5M00G7W      WCDMA            NaN
#
#         meioAcesso  FreqTxMHz  FreqRxMHz  Azimute CodTipoClasseEstacao  \
# 0              NaN     2160.0     1970.0    230.0                   FB
# 1              NaN     1862.5     1767.5    360.0                   FB
# 2              NaN     1862.5     1767.5    130.0                   FB
# 3              NaN     1867.5     1772.5    130.0                   FB
# 4              NaN     1867.5     1772.5    240.0                   FB
# ...            ...        ...        ...      ...                  ...
# 726315         NaN     1862.5     1767.5    120.0                   FB
# 726316         NaN     1862.5     1767.5    240.0                   FB
# 726317         NaN      874.5      829.5     20.0                   FB
# 726318         NaN      874.5      829.5    120.0                   FB
# 726319         NaN      874.5      829.5    240.0                   FB
#
#        ClassInfraFisica CompartilhamentoInfraFisica CodTipoAntena  \
# 0                   NaN                         NaN           760
# 1                   NaN                         NaN           760
# 2                   NaN                         NaN           760
# 3                   NaN                         NaN           760
# 4                   NaN                         NaN           760
# ...                 ...                         ...           ...
# 726315              NaN                         NaN           760
# 726316              NaN                         NaN           760
# 726317              NaN                         NaN           760
# 726318              NaN                         NaN           760
# 726319              NaN                         NaN           760
#
#        CodEquipamentoAntena GanhoAntena FrenteCostaAntena  \
# 0              002000703518        14.9                25
# 1              038801200762        17.8                25
# 2              038801200762        17.8                25
# 3              038801200762        17.8                25
# 4              038801200762        17.8                25
# ...                     ...         ...               ...
# 726315          56001603518        15.0                25
# 726316          56001603518        15.0                25
# 726317          56001603518        14.5                25
# 726318          56001603518        14.5                25
# 726319          56001603518        14.5                25
#
#        AnguloMeiaPotenciaAntena AnguloElevacao Polarizacao AlturaAntena  \
# 0                            70              6           X           41
# 1                            65              5           X           39
# 2                            65              5           X           39
# 3                            65              5           X           39
# 4                            65              5           X           39
# ...                         ...            ...         ...          ...
# 726315                       56              2           X           38
# 726316                       56              2           X           38
# 726317                       65              2           X           38
# 726318                       65              2           X           38
# 726319                       65              2           X           38
#
#        CodEquipamentoTransmissor PotenciaTransmissorWatts   Latitude  \
# 0                   018930701882                     39.4 -23.718890
# 1                   006030301882                     15.8 -23.718890
# 2                   006030301882                     15.8 -23.718890
# 3                   006030301882                     15.8 -23.718890
# 4                   006030301882                     15.8 -23.718890
# ...                          ...                      ...        ...
# 726315              040952002519                       40 -23.585382
# 726316              040952002519                       40 -23.585382
# 726317              000081201882                       40 -23.585382
# 726318              000081201882                       40 -23.585382
# 726319              000081201882                       40 -23.585382
#
#         Longitude CodDebitoTFI DataLicenciamento DataPrimeiroLicenciamento  \
# 0      -46.688890            G        2021-12-24                1999-12-10
# 1      -46.688890            G        2021-12-24                1999-12-10
# 2      -46.688890            G        2021-12-24                1999-12-10
# 3      -46.688890            G        2021-12-24                1999-12-10
# 4      -46.688890            G        2021-12-24                1999-12-10
# ...           ...          ...               ...                       ...
# 726315 -46.512821            G        2023-01-23                2014-11-24
# 726316 -46.512821            G        2023-01-23                2014-11-24
# 726317 -46.512821            G        2023-01-23                2014-11-24
# 726318 -46.512821            G        2023-01-23                2014-11-24
# 726319 -46.512821            G        2023-01-23                2014-11-24
#
#        NumRede               _id DataValidade  NumFistelAssociado  \
# 0          NaN     4d5c019f58e6a   2023-04-30                 NaN
# 1          NaN     4d5c019f58e6b   2023-04-30                 NaN
# 2          NaN     4d5c019f58e6c   2023-04-30                 NaN
# 3          NaN     4d5c019f58e6d   2023-04-30                 NaN
# 4          NaN     4d5c019f58e6e   2023-04-30                 NaN
# ...        ...               ...          ...                 ...
# 726315     NaN  762525f8473607c1   2029-12-08                 NaN
# 726316     NaN  762525f8473607c2   2029-12-08                 NaN
# 726317     NaN  762525f8473607c3   2029-12-08                 NaN
# 726318     NaN  762525f8473607c4   2029-12-08                 NaN
# 726319     NaN  762525f8473607c5   2029-12-08                 NaN
#
#        NomeEntidadeAssociado Tecnologia_gen
# 0                        NaN             3G
# 1                        NaN             2G
# 2                        NaN             2G
# 3                        NaN             2G
# 4                        NaN             2G
# ...                      ...            ...
# 726315                   NaN             4G
# 726316                   NaN             4G
# 726317                   NaN             3G
# 726318                   NaN             3G
# 726319                   NaN             3G
#
# [726320 rows x 41 columns]

# %%
def getCodUF(siglaUf):
    ufList = [{"CodUF":"11","SiglaUF":"RO"},{"CodUF":"14","SiglaUF":"RR"},{"CodUF":"16","SiglaUF":"AP"},{"CodUF":"17","SiglaUF":"TO"},{"CodUF":"22","SiglaUF":"PI"},{"CodUF":"24","SiglaUF":"RN"},{"CodUF":"26","SiglaUF":"PE"},{"CodUF":"29","SiglaUF":"BA"},{"CodUF":"33","SiglaUF":"RJ"},{"CodUF":"42","SiglaUF":"SC"},{"CodUF":"51","SiglaUF":"MT"},{"CodUF":"27","SiglaUF":"AL"},{"CodUF":"31","SiglaUF":"MG"},{"CodUF":"41","SiglaUF":"PR"},{"CodUF":"50","SiglaUF":"MS"},{"CodUF":"53","SiglaUF":"DF"},{"CodUF":"12","SiglaUF":"AC"},{"CodUF":"13","SiglaUF":"AM"},{"CodUF":"15","SiglaUF":"PA"},{"CodUF":"21","SiglaUF":"MA"},{"CodUF":"23","SiglaUF":"CE"},{"CodUF":"25","SiglaUF":"PB"},{"CodUF":"28","SiglaUF":"SE"},{"CodUF":"32","SiglaUF":"ES"},{"CodUF":"35","SiglaUF":"SP"},{"CodUF":"43","SiglaUF":"RS"},{"CodUF":"52","SiglaUF":"GO"}]
    for uf in ufList:
        if siglaUf == uf['SiglaUF']:
            return uf['CodUF']

    return None

# %%
def getUFMunicipios(siglaUf):
    CodUF = getCodUF(siglaUf)
    url = f'https://sistemas.anatel.gov.br/se/eApp/forms/b/jf_getMunicipios.php?CodUF={CodUF}'
    response = requests.get(url).text
    return json.loads(response)

# %%
def getMunicipioId(siglaUf, municipioName):
    municipiosList = getUFMunicipios(siglaUf)
    for mun in municipiosList:
        if municipioName == mun[0]:
            return int(mun[1])
    return None

# %%
#getCodUF('SP'), getMunicipioId('SP', 'São Paulo')
getUFMunicipios('DF'), getCodUF('DF'), getMunicipioId('DF', 'Brasília')
# Out:
# ([['Todos os Municipios', '5300000'],
#   ['Brasília', '5300108', -15.7989, -47.8667]],
#  '53',
#  5300108)

# %%
df = ERBs_SP_CLARO[(ERBs_SP_CLARO.distance < 2000) & (ERBs_SP_CLARO.Tecnologia == 'NR')]
#df.Latitude = df.Latitude.apply(lambda val: val + random.random() / 10**4)
#df.Longitude = df.Longitude.apply(lambda val: val + random.random() / 10**4)

# %%
import plotly.graph_objs as go
from tqdm import tqdm

# Load data from CSV file
data = df

# Create a scatter mapbox trace with arrow markers
fig = go.Figure()

# Add arrow markers for each data point
for _, row in tqdm(data.iterrows()):
    size = .0001
    random_pos = hash(row.FreqTxMHz) / 10**13.7
    random_rot = random.random() / 10**1
    if row['Azimute'] == 0:
        fig.add_trace(go.Scattermapbox(
            lat=data['Latitude'] + random_pos,
            lon=data['Longitude'] + random_pos,
            mode='markers',
            marker=dict(size=7, color='red', symbol='circle'),
        ))
    else:
        fig.add_trace(go.Scattermapbox(
            lat = [row['Latitude'] + random_pos, row['Latitude'] + size * np.cos(row['Azimute_rad'] + random_rot) + random_pos],
            lon = [row['Longitude'] + random_pos, row['Longitude'] + size * np.sin(row['Azimute_rad'] + random_rot) + random_pos],
            mode = 'lines',
            line = dict(width = 1.5, color = 'blue'),
        ))
# Out:
# 537it [00:00, 1506.41it/s]

# %%
# Set mapbox style and layout
fig.update_layout(
    mapbox=dict(
        #style= "carto-darkmatter",
        #style= "carto-positron",
        #style= "open-street-map",
        style= "stamen-toner",
        #style= "stamen-watercolor",
        #style= "white-bg",
        center=dict(lat=data['Latitude'].iloc[0], lon=data['Longitude'].iloc[0]),
        zoom=18),
    margin=dict(l=0, r=0, t=0, b=0),
    showlegend=False,
        width=1000, height=1000,
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="172e8314-a816-4f5e-ac48-c14559409027" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("172e8314-a816-4f5e-ac48-c14559409027")) {                    Plotly.newPlot(                        "172e8314-a816-4f5e-ac48-c14559409027",                        [{"lat":[-23.558649999947324,-23.555429999947325,-23.555429999947325,-23.555429999947325,-23.564999999947325,-23.564999999947325,-23.564999999947325,-23.566109999947322,-23.566109999947322,-23.566109999947322,-23.564799999947326,-23.564799999947326,-23.564799999947326,-23.560899999947324,-23.560899999947324,-23.560899999947324,-23.559309999947324,-23.559309999947324,-23.559309999947324,-23.560929999947323,-23.560929999947323,-23.560929999947323,-23.568829999947322,-23.568829999947322,-23.568829999947322,-23.550799999947323,-23.550799999947323,-23.550799999947323,-23.569919999947324,-23.569919999947324,-23.569919999947324,-23.568649999947326,-23.568649999947326,-23.568649999947326,-23.557699999947324,-23.557699999947324,-23.567599999947323,-23.567599999947323,-23.567599999947323,-23.560839999947323,-23.560839999947323,-23.560839999947323,-23.564339999947325,-23.564339999947325,-23.564339999947325,-23.558099999947324,-23.558099999947324,-23.558099999947324,-23.565099999947325,-23.565099999947325,-23.565099999947325,-23.564079999947324,-23.564079999947324,-23.564079999947324,-23.558099999947324,-23.558099999947324,-23.558099999947324,-23.563499999947325,-23.563499999947325,-23.563499999947325,-23.552699999947325,-23.552699999947325,-23.552699999947325,-23.569379999947323,-23.569379999947323,-23.569379999947323,-23.558649999947324,-23.558649999947324,-23.568589999947324,-23.568589999947324,-23.568589999947324,-23.558819999947325,-23.558819999947325,-23.558819999947325,-23.564139999947322,-23.564139999947322,-23.564139999947322,-23.557699999947324,-23.563499999947325,-23.563499999947325,-23.563499999947325,-23.555569999947323,-23.555569999947323,-23.555569999947323,-23.564139999947322,-23.564139999947322,-23.564139999947322,-23.564139999947322,-23.564139999947322,-23.564139999947322,-23.569449999947324,-23.569449999947324,-23.569449999947324,-23.569449999947324,-23.569449999947324,-23.569449999947324,-23.541119999947323,-23.541119999947323,-23.541119999947323,-23.541119999947323,-23.541119999947323,-23.541119999947323,-23.568829999947322,-23.568829999947322,-23.568829999947322,-23.568829999947322,-23.568829999947322,-23.568829999947322,-23.564999999947325,-23.564999999947325,-23.564999999947325,-23.564999999947325,-23.564999999947325,-23.564999999947325,-23.560929999947323,-23.560929999947323,-23.560929999947323,-23.560929999947323,-23.560929999947323,-23.560929999947323,-23.542329999947324,-23.542329999947324,-23.542329999947324,-23.542329999947324,-23.542329999947324,-23.542329999947324,-23.558559999947324,-23.558559999947324,-23.558559999947324,-23.558559999947324,-23.558559999947324,-23.558559999947324,-23.561389999947323,-23.561389999947323,-23.561389999947323,-23.561389999947323,-23.561389999947323,-23.561389999947323,-23.555679999947323,-23.555679999947323,-23.555679999947323,-23.555679999947323,-23.555679999947323,-23.555679999947323,-23.557699999947324,-23.557699999947324,-23.557699999947324,-23.557699999947324,-23.557699999947324,-23.557699999947324,-23.568649999947326,-23.568649999947326,-23.568649999947326,-23.568649999947326,-23.568649999947326,-23.568649999947326,-23.556569999947325,-23.556569999947325,-23.556569999947325,-23.556569999947325,-23.556569999947325,-23.556569999947325,-23.560899999947324,-23.560899999947324,-23.560899999947324,-23.560899999947324,-23.560899999947324,-23.560899999947324,-23.559309999947324,-23.559309999947324,-23.559309999947324,-23.559309999947324,- ...
